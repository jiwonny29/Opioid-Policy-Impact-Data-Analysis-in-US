# %% [markdown]
# # EDA on Given Two Datasets: Opioid Prescriptions and Vital Statistics Mortality Data

# %%
# Read Opioid Prescriptions dataset
import pandas as pd

file_path = r"C:/Users/wonny/Downloads/arcos_all_washpost/arcos_all_washpost.tsv"
chunksize = 200 

reader = pd.read_csv(file_path, delimiter='\t', chunksize=chunksize)
first_chunk = next(reader)

first_chunk.sample(20)
# Out:
#     REPORTER_DEA_NO REPORTER_BUS_ACT         REPORTER_NAME  \
# 130       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 19        RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 103       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 179       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 69        RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 131       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 10        RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 111       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 196       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 145       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 50        RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 199       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 16        RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 82        RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# 189       RM0220688      DISTRIBUTOR  MCKESSON CORPORATION
# ...

# %%
# Additional unique values need to be identified. 
# This comment refers to the fact that the current unique values are based on chunked data, 
# and further analysis or processing is required to find unique values across the entire dataset.

unique_values = first_chunk['REPORTER_BUS_ACT'].unique()
print(unique_values)
# Out:
# ['DISTRIBUTOR']

# %%
first_chunk.columns.tolist()
# Out:
# ['REPORTER_DEA_NO',
#  'REPORTER_BUS_ACT',
#  'REPORTER_NAME',
#  'REPORTER_ADDL_CO_INFO',
#  'REPORTER_ADDRESS1',
#  'REPORTER_ADDRESS2',
#  'REPORTER_CITY',
#  'REPORTER_STATE',
#  'REPORTER_ZIP',
#  'REPORTER_COUNTY',
#  'BUYER_DEA_NO',
#  'BUYER_BUS_ACT',
#  'BUYER_NAME',
#  'BUYER_ADDL_CO_INFO',
#  'BUYER_ADDRESS1',
#  'BUYER_ADDRESS2',
#  'BUYER_CITY',
#  'BUYER_STATE',
#  'BUYER_ZIP',
#  'BUYER_COUNTY',
#  'TRANSACTION_CODE',
#  'DRUG_CODE',
#  'NDC_NO',
#  'DRUG_NAME',
#  'Measure',
#  'MME_Conversion_Factor',
#  'Dosage_Strength',
#  'TRANSACTION_DATE',
#  'Combined_Labeler_Name',
#  'Reporter_family',
#  'CALC_BASE_WT_IN_GM',
#  'DOSAGE_UNIT',
#  'MME']

# %%
# Read Vital Statistics Mortality Data (2009)
file_path = r"C:/Users/wonny/Downloads/US_VitalStatistics/Underlying Cause of Death, 2009.txt"
death_data = pd.read_csv(file_path, delimiter='\t')  
death_data.sample(20)
# Out:
#      Notes                    County  County Code    Year  Year Code  \
# 428    NaN        Boulder County, CO       8013.0  2009.0     2009.0
# 3500   NaN      Jefferson County, TN      47089.0  2009.0     2009.0
# 439    NaN         Denver County, CO       8031.0  2009.0     2009.0
# 1692   NaN           York County, ME      23031.0  2009.0     2009.0
# 1517   NaN          Knott County, KY      21119.0  2009.0     2009.0
# 646    NaN       Okaloosa County, FL      12091.0  2009.0     2009.0
# 199    NaN          Izard County, AR       5065.0  2009.0     2009.0
# 4208   NaN         Marion County, WV      54049.0  2009.0     2009.0
# 219    NaN          Perry County, AR       5105.0  2009.0     2009.0
# 3552   NaN         Sumner County, TN      47165.0  2009.0     2009.0
# 2867   NaN         Towner County, ND      38095.0  2009.0     2009.0
# 3245   NaN         Lehigh County, PA      42077.0  2009.0     2009.0
# 3067   NaN          Noble County, OK      40103.0  2009.0     2009.0
# ...

# %%
death_data.describe()
# Out:
#         County Code    Year  Year Code        Deaths
# count   4364.000000  4364.0     4364.0   4364.000000
# mean   29697.025206  2009.0     2009.0    554.245417
# std    15391.570804     0.0        0.0   1754.076184
# min     1001.000000  2009.0     2009.0     10.000000
# 25%    17198.500000  2009.0     2009.0     35.000000
# 50%    29106.000000  2009.0     2009.0    148.000000
# 75%    42103.500000  2009.0     2009.0    409.000000
# max    56045.000000  2009.0     2009.0  55972.000000

# %%
death_data['County'].tolist()
# Out:
# ['Autauga County, AL',
#  'Baldwin County, AL',
#  'Baldwin County, AL',
#  'Barbour County, AL',
#  'Bibb County, AL',
#  'Blount County, AL',
#  'Bullock County, AL',
#  'Butler County, AL',
#  'Calhoun County, AL',
#  'Calhoun County, AL',
#  'Chambers County, AL',
#  'Cherokee County, AL',
#  'Chilton County, AL',
#  'Choctaw County, AL',
#  'Clarke County, AL',
#  'Clay County, AL',
#  'Cleburne County, AL',
#  'Coffee County, AL',
#  'Colbert County, AL',
#  'Conecuh County, AL',
#  'Coosa County, AL',
#  'Covington County, AL',
#  'Crenshaw County, AL',
#  'Cullman County, AL',
#  'Dale County, AL',
#  'Dallas County, AL',
#  'DeKalb County, AL',
#  'Elmore County, AL',
#  'Escambia County, AL',
#  'Escambia County, AL',
#  'Etowah County, AL',
#  'Etowah County, AL',
#  'Fayette County, AL',
#  'Franklin County, AL',
#  'Geneva County, AL',
#  'Greene County, AL',
#  'Hale County, AL',
#  'Henry County, AL',
#  'Houston County, AL',
#  'Houston County, AL',
# ...

# %%
# Year column check and there are some NaN values 
death_data['Year'].unique()
# Out:
# array([2009.,   nan])

# %%
# Print rows with NaN values in the 'Year' column and notes implies that it was maybe written during the data collection process.

year_nan_rows = death_data[death_data['Year'].isna()]
year_nan_rows
# Out:
#                                                   Notes County  County Code  \
# 4364                                                ---    NaN          NaN
# 4365      Dataset: Underlying Cause of Death, 1999-2017    NaN          NaN
# 4366                                  Query Parameters:    NaN          NaN
# 4367  Group By: County; Year; Drug/Alcohol Induced C...    NaN          NaN
# 4368                              Show Totals: Disabled    NaN          NaN
# 4369                         Show Zero Values: Disabled    NaN          NaN
# 4370                             Show Suppressed: False    NaN          NaN
# 4371                                                ---    NaN          NaN
# 4372  Help: See http://wonder.cdc.gov/wonder/help/uc...    NaN          NaN
# 4373                                                ---    NaN          NaN
# 4374  Suggested Citation: Centers for Disease Contro...    NaN          NaN
# ...

# %%
# Examine specific types of 'Drug/Alcohol Induced Causes' where there are 7 unique causes.
# Our focus is on 5 specific cases among the total 7 causes, including:
# 'Drug/Alcohol Induced Cause', 'Drug poisonings (overdose) Unintentional (X40-X44)',
# 'Drug poisonings (overdose) Suicide (X60-X64)', 'Drug poisonings (overdose) Undetermined (Y10-Y14)',
# and 'All other drug-induced causes'.

death_data['Drug/Alcohol Induced Cause'].value_counts()
# Out:
# Drug/Alcohol Induced Cause
# All other non-drug and non-alcohol causes             3100
# Drug poisonings (overdose) Unintentional (X40-X44)     571
# All other alcohol-induced causes                       438
# Drug poisonings (overdose) Suicide (X60-X64)           124
# Drug poisonings (overdose) Undetermined (Y10-Y14)       57
# Alcohol poisonings (overdose) (X45, X65, Y15)           38
# All other drug-induced causes                           36
# Name: count, dtype: int64

# %%
death_data['Drug/Alcohol Induced Cause Code'].value_counts()
# Out:
# Drug/Alcohol Induced Cause Code
# O9    3100
# D1     571
# A9     438
# D2     124
# D4      57
# A1      38
# D9      36
# Name: count, dtype: int64

# %%
# Read Underlying Cause of Death Data (2014)
# The data formats and column structures for different years are consistent, similar to the data from the year 2009.

file_path = r"C:/Users/wonny/Downloads/US_VitalStatistics/Underlying Cause of Death, 2014.txt"
df2 = pd.read_csv(file_path, delimiter='\t')  
df2.sample(20)
# Out:
#      Notes                      County  County Code    Year  Year Code  \
# 2008   NaN            Wayne County, MI      26163.0  2014.0     2014.0
# 652    NaN          Manatee County, FL      12081.0  2014.0     2014.0
# 1343   NaN          Kossuth County, IA      19109.0  2014.0     2014.0
# 4626   NaN         Converse County, WY      56009.0  2014.0     2014.0
# 1927   NaN         Isabella County, MI      26073.0  2014.0     2014.0
# 1768   NaN        Penobscot County, ME      23019.0  2014.0     2014.0
# 1512   NaN        Wyandotte County, KS      20209.0  2014.0     2014.0
# 252    NaN       Washington County, AR       5143.0  2014.0     2014.0
# 3511   NaN            Aiken County, SC      45003.0  2014.0     2014.0
# 2031   NaN           Dakota County, MN      27037.0  2014.0     2014.0
# 1459   NaN         Marshall County, KS      20117.0  2014.0     2014.0
# 2376   NaN  Lewis and Clark County, MT      30049.0  2014.0     2014.0
# ...

# %%
df2['County'].tolist()
# Out:
# ['Autauga County, AL',
#  'Baldwin County, AL',
#  'Baldwin County, AL',
#  'Baldwin County, AL',
#  'Barbour County, AL',
#  'Bibb County, AL',
#  'Blount County, AL',
#  'Blount County, AL',
#  'Bullock County, AL',
#  'Butler County, AL',
#  'Calhoun County, AL',
#  'Calhoun County, AL',
#  'Chambers County, AL',
#  'Cherokee County, AL',
#  'Chilton County, AL',
#  'Choctaw County, AL',
#  'Clarke County, AL',
#  'Clay County, AL',
#  'Cleburne County, AL',
#  'Coffee County, AL',
#  'Colbert County, AL',
#  'Conecuh County, AL',
#  'Coosa County, AL',
#  'Covington County, AL',
#  'Crenshaw County, AL',
#  'Cullman County, AL',
#  'Cullman County, AL',
#  'Dale County, AL',
#  'Dallas County, AL',
#  'DeKalb County, AL',
#  'Elmore County, AL',
#  'Escambia County, AL',
#  'Escambia County, AL',
#  'Etowah County, AL',
#  'Etowah County, AL',
#  'Fayette County, AL',
#  'Franklin County, AL',
#  'Geneva County, AL',
#  'Greene County, AL',
#  'Hale County, AL',
# ...

# %%
# In the 2014 data, there are rows with NaN values in every column except the Notes column.
# Consider removing these rows when merging to create the final base dataset.

df2[df2['Year'].isna()]
# Out:
#                                                   Notes County  County Code  \
# 4651                                                ---    NaN          NaN
# 4652      Dataset: Underlying Cause of Death, 1999-2017    NaN          NaN
# 4653                                  Query Parameters:    NaN          NaN
# 4654  Group By: County; Year; Drug/Alcohol Induced C...    NaN          NaN
# 4655                              Show Totals: Disabled    NaN          NaN
# 4656                         Show Zero Values: Disabled    NaN          NaN
# 4657                             Show Suppressed: False    NaN          NaN
# 4658                                                ---    NaN          NaN
# 4659  Help: See http://wonder.cdc.gov/wonder/help/uc...    NaN          NaN
# 4660                                                ---    NaN          NaN
# 4661  Suggested Citation: Centers for Disease Contro...    NaN          NaN
# ...
