# %% [markdown]
# # Exploratory Data Analysis
#
# In this notebook we will analyse the data of Washington, Texas and Florida, regarding three source of information,

# %%
import pandas as pd


url = "https://dl.dropboxusercontent.com/scl/fi/dzsz8qffzwyz9l3tftvgr/arcos_all_washpost_FL.parquet?rlkey=es6vf6um49wdedjf5ggohuv5d&dl=0"
data = pd.read_parquet(url)

# %%
chunk.head(10)
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT                       REPORTER_NAME  \
# 0       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 1       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 2       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 3       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 4       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 5       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 6       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 7       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 8       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
# 9       RA0464406      DISTRIBUTOR  AMERISOURCEBERGEN DRUG CORPORATION
#
#   REPORTER_ADDL_CO_INFO                    REPORTER_ADDRESS1  \
# 0                  None  10910 LEE VISTA BOULEVARD SUITE 401
# 1                  None  10910 LEE VISTA BOULEVARD SUITE 401
# ...

# %%
# Showing all the columns while printing
pd.set_option("display.max_columns", None)

# %%
data = pd.read_csv("../arcos_all_washpost_FL.tsv", sep="\t")
# Out:
# /var/folders/qq/17cwmxhd3jv_w07w8pf57y5r0000gn/T/ipykernel_95245/1512484618.py:1: DtypeWarning: Columns (3,5,13,15,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('../arcos_all_washpost_FL.tsv', sep='\t')
